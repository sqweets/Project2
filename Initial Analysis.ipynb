# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 4000)
pd.set_option('display.max_columns', 100)

# %%
#
# Read in the data files
#
year_1950_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1950.csv"
year_1951_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1951.csv"
year_1952_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1952.csv"
year_1953_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1953.csv"
year_1954_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1954.csv"
year_1955_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1955.csv"
year_1956_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1956.csv"
year_1957_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1957.csv"
year_1958_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1958.csv"
year_1959_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1959.csv"
year_1960_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1960.csv"
year_1961_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1961.csv"
year_1962_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1962.csv"
year_1963_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1963.csv"
year_1964_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1964.csv"
year_1965_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1965.csv"
year_1966_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1966.csv"
year_1967_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1967.csv"
year_1968_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1968.csv"
year_1969_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1969.csv"
year_1970_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1970.csv"
year_1971_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1971.csv"
year_1972_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1972.csv"
year_1973_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1973.csv"
year_1974_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1974.csv"
year_1975_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1975.csv"
year_1976_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1976.csv"
year_1977_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1977.csv"
year_1978_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1978.csv"
year_1979_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1979.csv"
year_1980_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1980.csv"
year_1981_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1981.csv"
year_1982_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1982.csv"
year_1983_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1983.csv"
year_1984_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1984.csv"
year_1985_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1985.csv"
year_1986_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1986.csv"
year_1987_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1987.csv"
year_1988_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1988.csv"
year_1989_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1989.csv"
year_1990_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1990.csv"
year_1991_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1991.csv"
year_1992_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1992.csv"
year_1993_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1993.csv"
year_1994_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1994.csv"
year_1995_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1995.csv"
year_1996_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1996.csv"
year_1997_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1997.csv"
year_1998_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1998.csv"
year_1999_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d1999.csv"
year_2000_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2000.csv"
year_2001_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2001.csv"
year_2002_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2002.csv"
year_2003_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2003.csv"
year_2004_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2004.csv"
year_2005_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2005.csv"
year_2006_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2006.csv"
year_2007_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2007.csv"
year_2008_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2008.csv"
year_2009_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2009.csv"
year_2010_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2010.csv"
year_2011_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2011.csv"
year_2012_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2012.csv"
year_2013_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2013.csv"
year_2014_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2014.csv"
year_2015_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2015.csv"
year_2016_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2016.csv"
year_2017_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2017.csv"
year_2018_orig = "tornado-data-csv/StormEvents_details-ftp_v1.0_d2018.csv"

#
# Create data frames
#
year_1950_df = pd.read_csv(year_1950_orig, low_memory=False)
year_1951_df = pd.read_csv(year_1951_orig, low_memory=False)
year_1952_df = pd.read_csv(year_1952_orig, low_memory=False)
year_1953_df = pd.read_csv(year_1953_orig, low_memory=False)
year_1954_df = pd.read_csv(year_1954_orig, low_memory=False)
year_1955_df = pd.read_csv(year_1955_orig, low_memory=False)
year_1956_df = pd.read_csv(year_1956_orig, low_memory=False)
year_1957_df = pd.read_csv(year_1957_orig, low_memory=False)
year_1958_df = pd.read_csv(year_1958_orig, low_memory=False)
year_1959_df = pd.read_csv(year_1959_orig, low_memory=False)
year_1960_df = pd.read_csv(year_1960_orig, low_memory=False)
year_1961_df = pd.read_csv(year_1961_orig, low_memory=False)
year_1962_df = pd.read_csv(year_1962_orig, low_memory=False)
year_1963_df = pd.read_csv(year_1963_orig, low_memory=False)
year_1964_df = pd.read_csv(year_1964_orig, low_memory=False)
year_1965_df = pd.read_csv(year_1965_orig, low_memory=False)
year_1966_df = pd.read_csv(year_1966_orig, low_memory=False)
year_1967_df = pd.read_csv(year_1967_orig, low_memory=False)
year_1968_df = pd.read_csv(year_1968_orig, low_memory=False)
year_1969_df = pd.read_csv(year_1969_orig, low_memory=False)
year_1970_df = pd.read_csv(year_1970_orig, low_memory=False)
year_1971_df = pd.read_csv(year_1971_orig, low_memory=False)
year_1972_df = pd.read_csv(year_1972_orig, low_memory=False)
year_1973_df = pd.read_csv(year_1973_orig, low_memory=False)
year_1974_df = pd.read_csv(year_1974_orig, low_memory=False)
year_1975_df = pd.read_csv(year_1975_orig, low_memory=False)
year_1976_df = pd.read_csv(year_1976_orig, low_memory=False)
year_1977_df = pd.read_csv(year_1977_orig, low_memory=False)
year_1978_df = pd.read_csv(year_1978_orig, low_memory=False)
year_1979_df = pd.read_csv(year_1979_orig, low_memory=False)
year_1980_df = pd.read_csv(year_1980_orig, low_memory=False)
year_1981_df = pd.read_csv(year_1981_orig, low_memory=False)
year_1982_df = pd.read_csv(year_1982_orig, low_memory=False)
year_1983_df = pd.read_csv(year_1983_orig, low_memory=False)
year_1984_df = pd.read_csv(year_1984_orig, low_memory=False)
year_1985_df = pd.read_csv(year_1985_orig, low_memory=False)
year_1986_df = pd.read_csv(year_1986_orig, low_memory=False)
year_1987_df = pd.read_csv(year_1987_orig, low_memory=False)
year_1988_df = pd.read_csv(year_1988_orig, low_memory=False)
year_1989_df = pd.read_csv(year_1989_orig, low_memory=False)
year_1990_df = pd.read_csv(year_1990_orig, low_memory=False)
year_1991_df = pd.read_csv(year_1991_orig, low_memory=False)
year_1992_df = pd.read_csv(year_1992_orig, low_memory=False)
year_1993_df = pd.read_csv(year_1993_orig, low_memory=False)
year_1994_df = pd.read_csv(year_1994_orig, low_memory=False)
year_1995_df = pd.read_csv(year_1995_orig, low_memory=False)
year_1996_df = pd.read_csv(year_1996_orig, low_memory=False)
year_1997_df = pd.read_csv(year_1997_orig, low_memory=False)
year_1998_df = pd.read_csv(year_1998_orig, low_memory=False)
year_1999_df = pd.read_csv(year_1999_orig, low_memory=False)
year_2000_df = pd.read_csv(year_2000_orig, low_memory=False)
year_2001_df = pd.read_csv(year_2001_orig, low_memory=False)
year_2002_df = pd.read_csv(year_2002_orig, low_memory=False)
year_2003_df = pd.read_csv(year_2003_orig, low_memory=False)
year_2004_df = pd.read_csv(year_2004_orig, low_memory=False)
year_2005_df = pd.read_csv(year_2005_orig, low_memory=False)
year_2006_df = pd.read_csv(year_2006_orig, low_memory=False)
year_2007_df = pd.read_csv(year_2007_orig, low_memory=False)
year_2008_df = pd.read_csv(year_2008_orig, low_memory=False)
year_2009_df = pd.read_csv(year_2009_orig, low_memory=False)
year_2010_df = pd.read_csv(year_2010_orig, low_memory=False)
year_2011_df = pd.read_csv(year_2011_orig, low_memory=False)
year_2012_df = pd.read_csv(year_2012_orig, low_memory=False)
year_2013_df = pd.read_csv(year_2013_orig, low_memory=False)
year_2014_df = pd.read_csv(year_2014_orig, low_memory=False)
year_2015_df = pd.read_csv(year_2015_orig, low_memory=False)
year_2016_df = pd.read_csv(year_2016_orig, low_memory=False)
year_2017_df = pd.read_csv(year_2017_orig, low_memory=False)
year_2018_df = pd.read_csv(year_2018_orig, low_memory=False)

# %%
#
# Make sure there are only tornado records
#
year_1950_trim1_df = year_1950_df.loc[year_1950_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1951_trim1_df = year_1951_df.loc[year_1951_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1952_trim1_df = year_1952_df.loc[year_1952_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1953_trim1_df = year_1953_df.loc[year_1953_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1954_trim1_df = year_1954_df.loc[year_1954_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1955_trim1_df = year_1955_df.loc[year_1955_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1956_trim1_df = year_1956_df.loc[year_1956_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1957_trim1_df = year_1957_df.loc[year_1957_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1958_trim1_df = year_1958_df.loc[year_1958_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1959_trim1_df = year_1959_df.loc[year_1959_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1960_trim1_df = year_1960_df.loc[year_1960_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1961_trim1_df = year_1961_df.loc[year_1961_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1962_trim1_df = year_1962_df.loc[year_1962_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1963_trim1_df = year_1963_df.loc[year_1963_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1964_trim1_df = year_1964_df.loc[year_1964_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1965_trim1_df = year_1965_df.loc[year_1965_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1966_trim1_df = year_1966_df.loc[year_1966_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1967_trim1_df = year_1967_df.loc[year_1967_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1968_trim1_df = year_1968_df.loc[year_1968_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1969_trim1_df = year_1969_df.loc[year_1969_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1970_trim1_df = year_1970_df.loc[year_1970_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1971_trim1_df = year_1971_df.loc[year_1971_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1972_trim1_df = year_1972_df.loc[year_1972_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1973_trim1_df = year_1973_df.loc[year_1973_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1974_trim1_df = year_1974_df.loc[year_1974_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1975_trim1_df = year_1975_df.loc[year_1975_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1976_trim1_df = year_1976_df.loc[year_1976_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1977_trim1_df = year_1977_df.loc[year_1977_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1978_trim1_df = year_1978_df.loc[year_1978_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1979_trim1_df = year_1979_df.loc[year_1979_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1980_trim1_df = year_1980_df.loc[year_1980_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1981_trim1_df = year_1981_df.loc[year_1981_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1982_trim1_df = year_1982_df.loc[year_1982_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1983_trim1_df = year_1983_df.loc[year_1983_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1984_trim1_df = year_1984_df.loc[year_1984_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1985_trim1_df = year_1985_df.loc[year_1985_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1986_trim1_df = year_1986_df.loc[year_1986_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1987_trim1_df = year_1987_df.loc[year_1987_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1988_trim1_df = year_1988_df.loc[year_1988_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1989_trim1_df = year_1989_df.loc[year_1989_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1990_trim1_df = year_1990_df.loc[year_1990_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1991_trim1_df = year_1991_df.loc[year_1991_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1992_trim1_df = year_1992_df.loc[year_1992_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1993_trim1_df = year_1993_df.loc[year_1993_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1994_trim1_df = year_1994_df.loc[year_1994_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1995_trim1_df = year_1995_df.loc[year_1995_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1996_trim1_df = year_1996_df.loc[year_1996_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1997_trim1_df = year_1997_df.loc[year_1997_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1998_trim1_df = year_1998_df.loc[year_1998_df['EVENT_TYPE'] == 'Tornado'].copy()
year_1999_trim1_df = year_1999_df.loc[year_1999_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2000_trim1_df = year_2000_df.loc[year_2000_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2001_trim1_df = year_2001_df.loc[year_2001_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2002_trim1_df = year_2002_df.loc[year_2002_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2003_trim1_df = year_2003_df.loc[year_2003_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2004_trim1_df = year_2004_df.loc[year_2004_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2005_trim1_df = year_2005_df.loc[year_2005_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2006_trim1_df = year_2006_df.loc[year_2006_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2007_trim1_df = year_2007_df.loc[year_2007_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2008_trim1_df = year_2008_df.loc[year_2008_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2009_trim1_df = year_2009_df.loc[year_2009_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2010_trim1_df = year_2010_df.loc[year_2010_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2011_trim1_df = year_2011_df.loc[year_2011_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2012_trim1_df = year_2012_df.loc[year_2012_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2013_trim1_df = year_2013_df.loc[year_2013_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2014_trim1_df = year_2014_df.loc[year_2014_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2015_trim1_df = year_2015_df.loc[year_2015_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2016_trim1_df = year_2016_df.loc[year_2016_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2017_trim1_df = year_2017_df.loc[year_2017_df['EVENT_TYPE'] == 'Tornado'].copy()
year_2018_trim1_df = year_2018_df.loc[year_2018_df['EVENT_TYPE'] == 'Tornado'].copy()

# %%
#
# Create dataframes with only the columns we are interested in
#
year_1950_trim2_df = year_1950_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1951_trim2_df = year_1951_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1952_trim2_df = year_1952_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1953_trim2_df = year_1953_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1954_trim2_df = year_1954_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1955_trim2_df = year_1955_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1956_trim2_df = year_1956_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1957_trim2_df = year_1957_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1958_trim2_df = year_1958_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1959_trim2_df = year_1959_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1960_trim2_df = year_1960_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1961_trim2_df = year_1961_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1962_trim2_df = year_1962_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1963_trim2_df = year_1963_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1964_trim2_df = year_1964_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1965_trim2_df = year_1965_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1966_trim2_df = year_1966_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1967_trim2_df = year_1967_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1968_trim2_df = year_1968_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1969_trim2_df = year_1969_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1970_trim2_df = year_1970_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1971_trim2_df = year_1971_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1972_trim2_df = year_1972_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1973_trim2_df = year_1973_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1974_trim2_df = year_1974_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1975_trim2_df = year_1975_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1976_trim2_df = year_1976_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1977_trim2_df = year_1977_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1978_trim2_df = year_1978_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1979_trim2_df = year_1979_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1980_trim2_df = year_1980_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1981_trim2_df = year_1981_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1982_trim2_df = year_1982_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1983_trim2_df = year_1983_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1984_trim2_df = year_1984_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1985_trim2_df = year_1985_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1986_trim2_df = year_1986_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1987_trim2_df = year_1987_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1988_trim2_df = year_1988_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1989_trim2_df = year_1989_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1990_trim2_df = year_1990_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1991_trim2_df = year_1991_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1992_trim2_df = year_1992_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1993_trim2_df = year_1993_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1994_trim2_df = year_1994_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1995_trim2_df = year_1995_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1996_trim2_df = year_1996_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1997_trim2_df = year_1997_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1998_trim2_df = year_1998_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_1999_trim2_df = year_1999_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2000_trim2_df = year_2000_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2001_trim2_df = year_2001_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2002_trim2_df = year_2002_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2003_trim2_df = year_2003_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2004_trim2_df = year_2004_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2005_trim2_df = year_2005_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2006_trim2_df = year_2006_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2007_trim2_df = year_2007_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2008_trim2_df = year_2008_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2009_trim2_df = year_2009_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2010_trim2_df = year_2010_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2011_trim2_df = year_2011_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2012_trim2_df = year_2012_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2013_trim2_df = year_2013_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2014_trim2_df = year_2014_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2015_trim2_df = year_2015_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2016_trim2_df = year_2016_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2017_trim2_df = year_2017_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()
year_2018_trim2_df = year_2018_trim1_df[['STATE', 'MONTH_NAME', 'TOR_F_SCALE']].copy()

# %%
#
# Pull out data for the 6 states in the original tornado alley
#
year_1950_trim3_df = year_1950_trim2_df.loc[year_1950_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1951_trim3_df = year_1951_trim2_df.loc[year_1951_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1952_trim3_df = year_1952_trim2_df.loc[year_1952_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1953_trim3_df = year_1953_trim2_df.loc[year_1953_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1954_trim3_df = year_1954_trim2_df.loc[year_1954_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1955_trim3_df = year_1955_trim2_df.loc[year_1955_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1956_trim3_df = year_1956_trim2_df.loc[year_1956_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1957_trim3_df = year_1957_trim2_df.loc[year_1957_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1958_trim3_df = year_1958_trim2_df.loc[year_1958_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1959_trim3_df = year_1959_trim2_df.loc[year_1959_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1960_trim3_df = year_1960_trim2_df.loc[year_1960_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1961_trim3_df = year_1961_trim2_df.loc[year_1961_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1962_trim3_df = year_1962_trim2_df.loc[year_1962_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1963_trim3_df = year_1963_trim2_df.loc[year_1963_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1964_trim3_df = year_1964_trim2_df.loc[year_1964_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1965_trim3_df = year_1965_trim2_df.loc[year_1965_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1966_trim3_df = year_1966_trim2_df.loc[year_1966_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1967_trim3_df = year_1967_trim2_df.loc[year_1967_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1968_trim3_df = year_1968_trim2_df.loc[year_1968_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1969_trim3_df = year_1969_trim2_df.loc[year_1969_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1970_trim3_df = year_1970_trim2_df.loc[year_1970_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1971_trim3_df = year_1971_trim2_df.loc[year_1971_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1972_trim3_df = year_1972_trim2_df.loc[year_1972_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1973_trim3_df = year_1973_trim2_df.loc[year_1973_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1974_trim3_df = year_1974_trim2_df.loc[year_1974_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1975_trim3_df = year_1975_trim2_df.loc[year_1975_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1976_trim3_df = year_1976_trim2_df.loc[year_1976_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1977_trim3_df = year_1977_trim2_df.loc[year_1977_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1978_trim3_df = year_1978_trim2_df.loc[year_1978_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1979_trim3_df = year_1979_trim2_df.loc[year_1979_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1980_trim3_df = year_1980_trim2_df.loc[year_1980_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1981_trim3_df = year_1981_trim2_df.loc[year_1981_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1982_trim3_df = year_1982_trim2_df.loc[year_1982_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1983_trim3_df = year_1983_trim2_df.loc[year_1983_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1984_trim3_df = year_1984_trim2_df.loc[year_1984_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1985_trim3_df = year_1985_trim2_df.loc[year_1985_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1986_trim3_df = year_1986_trim2_df.loc[year_1986_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1987_trim3_df = year_1987_trim2_df.loc[year_1987_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1988_trim3_df = year_1988_trim2_df.loc[year_1988_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1989_trim3_df = year_1989_trim2_df.loc[year_1989_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1990_trim3_df = year_1990_trim2_df.loc[year_1990_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1991_trim3_df = year_1991_trim2_df.loc[year_1991_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1992_trim3_df = year_1992_trim2_df.loc[year_1992_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1993_trim3_df = year_1993_trim2_df.loc[year_1993_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1994_trim3_df = year_1994_trim2_df.loc[year_1994_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1995_trim3_df = year_1995_trim2_df.loc[year_1995_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1996_trim3_df = year_1996_trim2_df.loc[year_1996_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1997_trim3_df = year_1997_trim2_df.loc[year_1997_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1998_trim3_df = year_1998_trim2_df.loc[year_1998_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_1999_trim3_df = year_1999_trim2_df.loc[year_1999_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2000_trim3_df = year_2000_trim2_df.loc[year_2000_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2001_trim3_df = year_2001_trim2_df.loc[year_2001_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2002_trim3_df = year_2002_trim2_df.loc[year_2002_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2003_trim3_df = year_2003_trim2_df.loc[year_2003_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2004_trim3_df = year_2004_trim2_df.loc[year_2004_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2005_trim3_df = year_2005_trim2_df.loc[year_2005_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2006_trim3_df = year_2006_trim2_df.loc[year_2006_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2007_trim3_df = year_2007_trim2_df.loc[year_2007_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2008_trim3_df = year_2008_trim2_df.loc[year_2008_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2009_trim3_df = year_2009_trim2_df.loc[year_2009_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2010_trim3_df = year_2010_trim2_df.loc[year_2010_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2011_trim3_df = year_2011_trim2_df.loc[year_2011_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2012_trim3_df = year_2012_trim2_df.loc[year_2012_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2013_trim3_df = year_2013_trim2_df.loc[year_2013_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2014_trim3_df = year_2014_trim2_df.loc[year_2014_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2015_trim3_df = year_2015_trim2_df.loc[year_2015_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2016_trim3_df = year_2016_trim2_df.loc[year_2016_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2017_trim3_df = year_2017_trim2_df.loc[year_2017_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()
year_2018_trim3_df = year_2018_trim2_df.loc[year_2018_trim2_df['STATE'].isin(['TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA'])].copy()

# %%
#
# Pull out data for the "sometimes" states in the original tornado alley
#
year_1950_trim4_df = year_1950_trim2_df.loc[year_1950_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1951_trim4_df = year_1951_trim2_df.loc[year_1951_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1952_trim4_df = year_1952_trim2_df.loc[year_1952_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1953_trim4_df = year_1953_trim2_df.loc[year_1953_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1954_trim4_df = year_1954_trim2_df.loc[year_1954_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1955_trim4_df = year_1955_trim2_df.loc[year_1955_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1956_trim4_df = year_1956_trim2_df.loc[year_1956_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1957_trim4_df = year_1957_trim2_df.loc[year_1957_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1958_trim4_df = year_1958_trim2_df.loc[year_1958_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1959_trim4_df = year_1959_trim2_df.loc[year_1959_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1960_trim4_df = year_1960_trim2_df.loc[year_1960_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1961_trim4_df = year_1961_trim2_df.loc[year_1961_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1962_trim4_df = year_1962_trim2_df.loc[year_1962_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1963_trim4_df = year_1963_trim2_df.loc[year_1963_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1964_trim4_df = year_1964_trim2_df.loc[year_1964_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1965_trim4_df = year_1965_trim2_df.loc[year_1965_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1966_trim4_df = year_1966_trim2_df.loc[year_1966_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1967_trim4_df = year_1967_trim2_df.loc[year_1967_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1968_trim4_df = year_1968_trim2_df.loc[year_1968_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1969_trim4_df = year_1969_trim2_df.loc[year_1969_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1970_trim4_df = year_1970_trim2_df.loc[year_1970_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1971_trim4_df = year_1971_trim2_df.loc[year_1971_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1972_trim4_df = year_1972_trim2_df.loc[year_1972_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1973_trim4_df = year_1973_trim2_df.loc[year_1973_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1974_trim4_df = year_1974_trim2_df.loc[year_1974_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1975_trim4_df = year_1975_trim2_df.loc[year_1975_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1976_trim4_df = year_1976_trim2_df.loc[year_1976_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1977_trim4_df = year_1977_trim2_df.loc[year_1977_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1978_trim4_df = year_1978_trim2_df.loc[year_1978_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1979_trim4_df = year_1979_trim2_df.loc[year_1979_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1980_trim4_df = year_1980_trim2_df.loc[year_1980_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1981_trim4_df = year_1981_trim2_df.loc[year_1981_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1982_trim4_df = year_1982_trim2_df.loc[year_1982_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1983_trim4_df = year_1983_trim2_df.loc[year_1983_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1984_trim4_df = year_1984_trim2_df.loc[year_1984_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1985_trim4_df = year_1985_trim2_df.loc[year_1985_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1986_trim4_df = year_1986_trim2_df.loc[year_1986_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1987_trim4_df = year_1987_trim2_df.loc[year_1987_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1988_trim4_df = year_1988_trim2_df.loc[year_1988_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1989_trim4_df = year_1989_trim2_df.loc[year_1989_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1990_trim4_df = year_1990_trim2_df.loc[year_1990_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1991_trim4_df = year_1991_trim2_df.loc[year_1991_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1992_trim4_df = year_1992_trim2_df.loc[year_1992_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1993_trim4_df = year_1993_trim2_df.loc[year_1993_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1994_trim4_df = year_1994_trim2_df.loc[year_1994_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1995_trim4_df = year_1995_trim2_df.loc[year_1995_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1996_trim4_df = year_1996_trim2_df.loc[year_1996_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1997_trim4_df = year_1997_trim2_df.loc[year_1997_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1998_trim4_df = year_1998_trim2_df.loc[year_1998_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_1999_trim4_df = year_1999_trim2_df.loc[year_1999_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2000_trim4_df = year_2000_trim2_df.loc[year_2000_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2001_trim4_df = year_2001_trim2_df.loc[year_2001_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2002_trim4_df = year_2002_trim2_df.loc[year_2002_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2003_trim4_df = year_2003_trim2_df.loc[year_2003_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2004_trim4_df = year_2004_trim2_df.loc[year_2004_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2005_trim4_df = year_2005_trim2_df.loc[year_2005_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2006_trim4_df = year_2006_trim2_df.loc[year_2006_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2007_trim4_df = year_2007_trim2_df.loc[year_2007_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2008_trim4_df = year_2008_trim2_df.loc[year_2008_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2009_trim4_df = year_2009_trim2_df.loc[year_2009_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2010_trim4_df = year_2010_trim2_df.loc[year_2010_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2011_trim4_df = year_2011_trim2_df.loc[year_2011_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2012_trim4_df = year_2012_trim2_df.loc[year_2012_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2013_trim4_df = year_2013_trim2_df.loc[year_2013_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2014_trim4_df = year_2014_trim2_df.loc[year_2014_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2015_trim4_df = year_2015_trim2_df.loc[year_2015_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2016_trim4_df = year_2016_trim2_df.loc[year_2016_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2017_trim4_df = year_2017_trim2_df.loc[year_2017_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()
year_2018_trim4_df = year_2018_trim2_df.loc[year_2018_trim2_df['STATE'].isin(['IOWA', 'MISSOURI', 'ILLINOIS', 'INDIANA', 'OHIO'])].copy()

# %%
#
# Get the F/EF values from the decade dataframes counts
#
def formatDataForPlotting(decade_counts, decade):
    f_result = []
    ef_result = []
    
    if (decade == "00"):
        # Get both F annd EF data and add together
        f_result = f_scales(decade_counts)
        ef_result = ef_scales(decade_counts)
        
        # Add the F and EF scale values
        result = [sum(x) for x in zip(f_result, ef_result)]
    elif (decade == "10"):
        # Get EF only
        result = ef_scales(decade_counts)
    else:
        # Get F only
        result = f_scales(decade_counts)
    
    return result

#------------------------------------------
def f_scales(decade_counts):
    f_result = []

    try:
        f_result.append(decade_counts.F0)
    except AttributeError:
        f_result.append(0)

    try:
        f_result.append(decade_counts.F1)
    except AttributeError:
        f_result.append(0)

    try:
        f_result.append(decade_counts.F2)
    except AttributeError:
        f_result.append(0)

    try:
        f_result.append(decade_counts.F3)
    except AttributeError:
        f_result.append(0)

    try:
        f_result.append(decade_counts.F4)
    except AttributeError:
        f_result.append(0)

    try:
        f_result.append(decade_counts.F5)
    except AttributeError:
        f_result.append(0)
        
    return f_result

#------------------------------------------
def ef_scales(decade_counts):
    ef_result = []

    try:
        ef_result.append(decade_counts.EF0)
    except AttributeError:
        ef_result.append(0)

    try:
        ef_result.append(decade_counts.EF1)
    except AttributeError:
        ef_result.append(0)

    try:
        ef_result.append(decade_counts.EF2)
    except AttributeError:
        ef_result.append(0)

    try:
        ef_result.append(decade_counts.EF3)
    except AttributeError:
        ef_result.append(0)

    try:
        ef_result.append(decade_counts.EF4)
    except AttributeError:
        ef_result.append(0)

    try:
        ef_result.append(decade_counts.EF5)
    except AttributeError:
        ef_result.append(0)
        
    return ef_result

# %%
#
# Create decade dataframes
#
decade_50 = [year_1950_trim3_df, year_1951_trim3_df, year_1952_trim3_df, year_1953_trim3_df, year_1954_trim3_df,
           year_1955_trim3_df, year_1956_trim3_df, year_1957_trim3_df, year_1958_trim3_df, year_1959_trim3_df]
decade_50_df = pd.concat(decade_50, ignore_index=True)

decade_60 = [year_1960_trim3_df, year_1961_trim3_df, year_1962_trim3_df, year_1963_trim3_df, year_1964_trim3_df,
            year_1965_trim3_df, year_1966_trim3_df, year_1967_trim3_df, year_1968_trim3_df, year_1969_trim3_df]
decade_60_df = pd.concat(decade_60, ignore_index=True)

decade_70 = [year_1970_trim3_df, year_1971_trim3_df, year_1972_trim3_df, year_1973_trim3_df, year_1974_trim3_df,
            year_1975_trim3_df, year_1976_trim3_df, year_1977_trim3_df, year_1978_trim3_df, year_1979_trim3_df]
decade_70_df = pd.concat(decade_70, ignore_index=True)

decade_80 = [year_1980_trim3_df, year_1981_trim3_df, year_1982_trim3_df, year_1983_trim3_df, year_1984_trim3_df,
            year_1985_trim3_df, year_1986_trim3_df, year_1987_trim3_df, year_1988_trim3_df, year_1989_trim3_df]
decade_80_df = pd.concat(decade_80, ignore_index=True)

decade_90 = [year_1990_trim3_df, year_1991_trim3_df, year_1992_trim3_df, year_1993_trim3_df, year_1994_trim3_df,
            year_1995_trim3_df, year_1996_trim3_df, year_1997_trim3_df, year_1998_trim3_df, year_1999_trim3_df]
decade_90_df = pd.concat(decade_90, ignore_index=True)

decade_00 = [year_2000_trim3_df, year_2001_trim3_df, year_2002_trim3_df, year_2003_trim3_df, year_2004_trim3_df,
            year_2005_trim3_df, year_2006_trim3_df, year_2007_trim3_df, year_2008_trim3_df, year_2009_trim3_df]
decade_00_df = pd.concat(decade_00, ignore_index=True)

decade_10 = [year_2010_trim3_df, year_2011_trim3_df, year_2012_trim3_df, year_2013_trim3_df, year_2014_trim3_df,
            year_2015_trim3_df, year_2016_trim3_df, year_2017_trim3_df, year_2018_trim3_df]
decade_10_df = pd.concat(decade_10, ignore_index=True)

# %%
#
# Get the counts (all tornados) for the 6 original torado alley states
# ('TEXAS','OKLAHOMA', 'KANSAS', 'NEBRASKA', 'COLORADO', 'SOUTH DAKOTA')
#

# Count the unique state entries
counts_all_50 = decade_50_df['STATE'].value_counts()
counts_all_60 = decade_60_df['STATE'].value_counts()
counts_all_70 = decade_70_df['STATE'].value_counts()
counts_all_80 = decade_80_df['STATE'].value_counts()
counts_all_90 = decade_90_df['STATE'].value_counts()
counts_all_00 = decade_00_df['STATE'].value_counts()
counts_all_10 = decade_10_df['STATE'].value_counts()

# Setup the line plot for the 6 states
texas_data    = (counts_all_50['TEXAS'], counts_all_60['TEXAS'], counts_all_70['TEXAS'], counts_all_80['TEXAS'],
                 counts_all_90['TEXAS'], counts_all_00['TEXAS'], counts_all_10['TEXAS'])
oklahoma_data = (counts_all_50['OKLAHOMA'], counts_all_60['OKLAHOMA'], counts_all_70['OKLAHOMA'], counts_all_80['OKLAHOMA'],
                 counts_all_90['OKLAHOMA'], counts_all_00['OKLAHOMA'], counts_all_10['OKLAHOMA'])
kansas_data   = (counts_all_50['KANSAS'], counts_all_60['KANSAS'], counts_all_70['KANSAS'], counts_all_80['KANSAS'],
                 counts_all_90['KANSAS'], counts_all_00['KANSAS'], counts_all_10['KANSAS'])
nebraska_data = (counts_all_50['NEBRASKA'], counts_all_60['NEBRASKA'], counts_all_70['NEBRASKA'], counts_all_80['NEBRASKA'],
                 counts_all_90['NEBRASKA'], counts_all_00['NEBRASKA'], counts_all_10['NEBRASKA'])
colorado_data = (counts_all_50['COLORADO'], counts_all_60['COLORADO'], counts_all_70['COLORADO'], counts_all_80['COLORADO'],
                 counts_all_90['COLORADO'], counts_all_00['COLORADO'], counts_all_10['COLORADO'])
sdakota_data  = (counts_all_50['SOUTH DAKOTA'], counts_all_60['SOUTH DAKOTA'], counts_all_70['SOUTH DAKOTA'], counts_all_80['SOUTH DAKOTA'],
                 counts_all_90['SOUTH DAKOTA'], counts_all_00['SOUTH DAKOTA'], counts_all_10['SOUTH DAKOTA'])


x_axis = ['1950s', '1960s', '1970s', '1980s', '1990s', '2000s', '2010s']

# Do the plotting
texas_handle    = plt.plot(x_axis, texas_data, label="Texas")
oklahoma_handle = plt.plot(x_axis, oklahoma_data, label="Oklahoma")
kansas_handle   = plt.plot(x_axis, kansas_data, label="Kansas")
nebraska_handle = plt.plot(x_axis, nebraska_data, label="Nebraska")
colorado_handle = plt.plot(x_axis, colorado_data, label="Colorado")
sdakota_handle  = plt.plot(x_axis, sdakota_data, label="South Dakota")

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='both', alpha=0.5)
plt.xlabel("Decade", fontsize = 22)
plt.ylabel("Tornado Count", fontsize = 22)
plt.title('Tornados per Decade (for TA states)', fontsize = 26)
plt.xticks(rotation=90)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=16)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/tornados_per_decade_line.png")

# %%
# Show plot
plt.show()

# %%
#
# Get the counts (of each strength category) for the 6 original torado alley states
# One plot per state
# This one is for Texas
#

# Count the unique scales (if NaN, discarded)
state_50_df = decade_50_df.loc[decade_50_df['STATE'] == 'TEXAS'].copy()
state_60_df = decade_60_df.loc[decade_60_df['STATE'] == 'TEXAS'].copy()
state_70_df = decade_70_df.loc[decade_70_df['STATE'] == 'TEXAS'].copy()
state_80_df = decade_80_df.loc[decade_80_df['STATE'] == 'TEXAS'].copy()
state_90_df = decade_90_df.loc[decade_90_df['STATE'] == 'TEXAS'].copy()
state_00_df = decade_00_df.loc[decade_00_df['STATE'] == 'TEXAS'].copy()
state_10_df = decade_10_df.loc[decade_10_df['STATE'] == 'TEXAS'].copy()

# Get unique counts (value_counts defaults to NOT count blanks)
state_50_scales = state_50_df['TOR_F_SCALE'].value_counts()
state_60_scales = state_60_df['TOR_F_SCALE'].value_counts()
state_70_scales = state_70_df['TOR_F_SCALE'].value_counts()
state_80_scales = state_80_df['TOR_F_SCALE'].value_counts()
state_90_scales = state_90_df['TOR_F_SCALE'].value_counts()
state_00_scales = state_00_df['TOR_F_SCALE'].value_counts()
state_10_scales = state_10_df['TOR_F_SCALE'].value_counts()

# Build the plot
# Setup the bar plot for the 6 levels
state_levels_50 = formatDataForPlotting(state_50_scales, "50")
                  
state_levels_60 = formatDataForPlotting(state_60_scales, "60")
                  
state_levels_70 = formatDataForPlotting(state_70_scales, "70")
                  
state_levels_80 = formatDataForPlotting(state_80_scales, "80")
                  
state_levels_90 = formatDataForPlotting(state_90_scales, "90")
                  
state_levels_00 = formatDataForPlotting(state_00_scales, "00")
                                
state_levels_10 = formatDataForPlotting(state_10_scales, "10")

# Set up the bar chart
x_axis = ['F0/EF0', 'F1/EF1', 'F2/EF2', 'F3/EF3', 'F4/EF4', 'F5/EF5']
_x_axis = np.arange(len(x_axis))

plt.bar(_x_axis - 0.3, state_levels_50, width=0.1, label="1950s")
plt.bar(_x_axis - 0.2, state_levels_60, width=0.1, label="1960s")
plt.bar(_x_axis - 0.1, state_levels_70, width=0.1, label="1970s")
plt.bar(_x_axis - 0.0, state_levels_80, width=0.1, label="1980s")
plt.bar(_x_axis + 0.1, state_levels_90, width=0.1, label="1990s")
plt.bar(_x_axis + 0.2, state_levels_00, width=0.1, label="2000s")
plt.bar(_x_axis + 0.3, state_levels_10, width=0.1, label="2010s")
plt.xticks(_x_axis, x_axis) # set labels manually

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='y', alpha=0.4)
plt.xlabel("F/EF Level", fontsize = 22)
plt.ylabel("Number of Tornados", fontsize = 22)
plt.title('Number of Tornados by F/EF Scale (TEXAS)', fontsize = 26)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/number_tornados_scale_texas.png", bbox_inches="tight")

# %%
# Show plot
plt.show()

# %%
#
# Get the counts (of each strength category) for the 6 original torado alley states
# One plot per state
# THIS ONE IS FOR OKLAHOMA
#

# Count the unique scales (if NaN, discarded)
state_50_df = decade_50_df.loc[decade_50_df['STATE'] == 'OKLAHOMA'].copy()
state_60_df = decade_60_df.loc[decade_60_df['STATE'] == 'OKLAHOMA'].copy()
state_70_df = decade_70_df.loc[decade_70_df['STATE'] == 'OKLAHOMA'].copy()
state_80_df = decade_80_df.loc[decade_80_df['STATE'] == 'OKLAHOMA'].copy()
state_90_df = decade_90_df.loc[decade_90_df['STATE'] == 'OKLAHOMA'].copy()
state_00_df = decade_00_df.loc[decade_00_df['STATE'] == 'OKLAHOMA'].copy()
state_10_df = decade_10_df.loc[decade_10_df['STATE'] == 'OKLAHOMA'].copy()

# Get unique counts (value_counts defaults to NOT count blanks)
state_50_scales = state_50_df['TOR_F_SCALE'].value_counts()
state_60_scales = state_60_df['TOR_F_SCALE'].value_counts()
state_70_scales = state_70_df['TOR_F_SCALE'].value_counts()
state_80_scales = state_80_df['TOR_F_SCALE'].value_counts()
state_90_scales = state_90_df['TOR_F_SCALE'].value_counts()
state_00_scales = state_00_df['TOR_F_SCALE'].value_counts()
state_10_scales = state_10_df['TOR_F_SCALE'].value_counts()

# Build the plot
# Setup the bar plot for the 6 levels
state_levels_50 = formatDataForPlotting(state_50_scales, "50")
                  
state_levels_60 = formatDataForPlotting(state_60_scales, "60")
                  
state_levels_70 = formatDataForPlotting(state_70_scales, "70")
                  
state_levels_80 = formatDataForPlotting(state_80_scales, "80")
                  
state_levels_90 = formatDataForPlotting(state_90_scales, "90")
                  
state_levels_00 = formatDataForPlotting(state_00_scales, "00")
                                
state_levels_10 = formatDataForPlotting(state_10_scales, "10")

# Set up the bar chart
x_axis = ['F0/EF0', 'F1/EF1', 'F2/EF2', 'F3/EF3', 'F4/EF4', 'F5/EF5']
_x_axis = np.arange(len(x_axis))

plt.bar(_x_axis - 0.3, state_levels_50, width=0.1, label="1950s")
plt.bar(_x_axis - 0.2, state_levels_60, width=0.1, label="1960s")
plt.bar(_x_axis - 0.1, state_levels_70, width=0.1, label="1970s")
plt.bar(_x_axis - 0.0, state_levels_80, width=0.1, label="1980s")
plt.bar(_x_axis + 0.1, state_levels_90, width=0.1, label="1990s")
plt.bar(_x_axis + 0.2, state_levels_00, width=0.1, label="2000s")
plt.bar(_x_axis + 0.3, state_levels_10, width=0.1, label="2010s")
plt.xticks(_x_axis, x_axis) # set labels manually

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='y', alpha=0.4)
plt.xlabel("F/EF Level", fontsize = 22)
plt.ylabel("Number of Tornados", fontsize = 22)
plt.title('Number of Tornados by F/EF Scale (OKLAHOMA)', fontsize = 26)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/number_tornados_scale_oklahoma.png", bbox_inches="tight")

# %%
# Show plot
plt.show()

# %%
#
# Get the counts (of each strength category) for the 6 original torado alley states
# One plot per state
# THIS ONE IS FOR KANSAS
#

# Count the unique scales (if NaN, discarded)
state_50_df = decade_50_df.loc[decade_50_df['STATE'] == 'KANSAS'].copy()
state_60_df = decade_60_df.loc[decade_60_df['STATE'] == 'KANSAS'].copy()
state_70_df = decade_70_df.loc[decade_70_df['STATE'] == 'KANSAS'].copy()
state_80_df = decade_80_df.loc[decade_80_df['STATE'] == 'KANSAS'].copy()
state_90_df = decade_90_df.loc[decade_90_df['STATE'] == 'KANSAS'].copy()
state_00_df = decade_00_df.loc[decade_00_df['STATE'] == 'KANSAS'].copy()
state_10_df = decade_10_df.loc[decade_10_df['STATE'] == 'KANSAS'].copy()

# Get unique counts (value_counts defaults to NOT count blanks)
state_50_scales = state_50_df['TOR_F_SCALE'].value_counts()
state_60_scales = state_60_df['TOR_F_SCALE'].value_counts()
state_70_scales = state_70_df['TOR_F_SCALE'].value_counts()
state_80_scales = state_80_df['TOR_F_SCALE'].value_counts()
state_90_scales = state_90_df['TOR_F_SCALE'].value_counts()
state_00_scales = state_00_df['TOR_F_SCALE'].value_counts()
state_10_scales = state_10_df['TOR_F_SCALE'].value_counts()

# Build the plot
# Setup the bar plot for the 6 levels
state_levels_50 = formatDataForPlotting(state_50_scales, "50")
                  
state_levels_60 = formatDataForPlotting(state_60_scales, "60")
                  
state_levels_70 = formatDataForPlotting(state_70_scales, "70")
                  
state_levels_80 = formatDataForPlotting(state_80_scales, "80")
                  
state_levels_90 = formatDataForPlotting(state_90_scales, "90")
                  
state_levels_00 = formatDataForPlotting(state_00_scales, "00")
                                
state_levels_10 = formatDataForPlotting(state_10_scales, "10")

# Set up the bar chart
x_axis = ['F0/EF0', 'F1/EF1', 'F2/EF2', 'F3/EF3', 'F4/EF4', 'F5/EF5']
_x_axis = np.arange(len(x_axis))

plt.bar(_x_axis - 0.3, state_levels_50, width=0.1, label="1950s")
plt.bar(_x_axis - 0.2, state_levels_60, width=0.1, label="1960s")
plt.bar(_x_axis - 0.1, state_levels_70, width=0.1, label="1970s")
plt.bar(_x_axis - 0.0, state_levels_80, width=0.1, label="1980s")
plt.bar(_x_axis + 0.1, state_levels_90, width=0.1, label="1990s")
plt.bar(_x_axis + 0.2, state_levels_00, width=0.1, label="2000s")
plt.bar(_x_axis + 0.3, state_levels_10, width=0.1, label="2010s")
plt.xticks(_x_axis, x_axis) # set labels manually

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='y', alpha=0.4)
plt.xlabel("F/EF Level", fontsize = 22)
plt.ylabel("Number of Tornados", fontsize = 22)
plt.title('Number of Tornados by F/EF Scale (KANSAS)', fontsize = 26)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/number_tornados_scale_kansas.png", bbox_inches="tight")

# %%
# Show plot
plt.show()

# %%
#
# Get the counts (of each strength category) for the 6 original torado alley states
# One plot per state
# THIS ONE IS FOR NEBRASKA
#

# Count the unique scales (if NaN, discarded)
state_50_df = decade_50_df.loc[decade_50_df['STATE'] == 'NEBRASKA'].copy()
state_60_df = decade_60_df.loc[decade_60_df['STATE'] == 'NEBRASKA'].copy()
state_70_df = decade_70_df.loc[decade_70_df['STATE'] == 'NEBRASKA'].copy()
state_80_df = decade_80_df.loc[decade_80_df['STATE'] == 'NEBRASKA'].copy()
state_90_df = decade_90_df.loc[decade_90_df['STATE'] == 'NEBRASKA'].copy()
state_00_df = decade_00_df.loc[decade_00_df['STATE'] == 'NEBRASKA'].copy()
state_10_df = decade_10_df.loc[decade_10_df['STATE'] == 'NEBRASKA'].copy()

# Get unique counts (value_counts defaults to NOT count blanks)
state_50_scales = state_50_df['TOR_F_SCALE'].value_counts()
state_60_scales = state_60_df['TOR_F_SCALE'].value_counts()
state_70_scales = state_70_df['TOR_F_SCALE'].value_counts()
state_80_scales = state_80_df['TOR_F_SCALE'].value_counts()
state_90_scales = state_90_df['TOR_F_SCALE'].value_counts()
state_00_scales = state_00_df['TOR_F_SCALE'].value_counts()
state_10_scales = state_10_df['TOR_F_SCALE'].value_counts()

# Build the plot
# Setup the bar plot for the 6 levels
state_levels_50 = formatDataForPlotting(state_50_scales, "50")
                  
state_levels_60 = formatDataForPlotting(state_60_scales, "60")
                  
state_levels_70 = formatDataForPlotting(state_70_scales, "70")
                  
state_levels_80 = formatDataForPlotting(state_80_scales, "80")
                  
state_levels_90 = formatDataForPlotting(state_90_scales, "90")
                  
state_levels_00 = formatDataForPlotting(state_00_scales, "00")
                                
state_levels_10 = formatDataForPlotting(state_10_scales, "10")

# Set up the bar chart
x_axis = ['F0/EF0', 'F1/EF1', 'F2/EF2', 'F3/EF3', 'F4/EF4', 'F5/EF5']
_x_axis = np.arange(len(x_axis))

plt.bar(_x_axis - 0.3, state_levels_50, width=0.1, label="1950s")
plt.bar(_x_axis - 0.2, state_levels_60, width=0.1, label="1960s")
plt.bar(_x_axis - 0.1, state_levels_70, width=0.1, label="1970s")
plt.bar(_x_axis - 0.0, state_levels_80, width=0.1, label="1980s")
plt.bar(_x_axis + 0.1, state_levels_90, width=0.1, label="1990s")
plt.bar(_x_axis + 0.2, state_levels_00, width=0.1, label="2000s")
plt.bar(_x_axis + 0.3, state_levels_10, width=0.1, label="2010s")
plt.xticks(_x_axis, x_axis) # set labels manually

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='y', alpha=0.4)
plt.xlabel("F/EF Level", fontsize = 22)
plt.ylabel("Number of Tornados", fontsize = 22)
plt.title('Number of Tornados by F/EF Scale (NEBRASKA)', fontsize = 26)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/number_tornados_scale_nebraska.png", bbox_inches="tight")

# %%
# Show plot
plt.show()

# %%
#
# Get the counts (of each strength category) for the 6 original torado alley states
# One plot per state
# THIS ONE IS FOR COLORADO
#

# Count the unique scales (if NaN, discarded)
state_50_df = decade_50_df.loc[decade_50_df['STATE'] == 'COLORADO'].copy()
state_60_df = decade_60_df.loc[decade_60_df['STATE'] == 'COLORADO'].copy()
state_70_df = decade_70_df.loc[decade_70_df['STATE'] == 'COLORADO'].copy()
state_80_df = decade_80_df.loc[decade_80_df['STATE'] == 'COLORADO'].copy()
state_90_df = decade_90_df.loc[decade_90_df['STATE'] == 'COLORADO'].copy()
state_00_df = decade_00_df.loc[decade_00_df['STATE'] == 'COLORADO'].copy()
state_10_df = decade_10_df.loc[decade_10_df['STATE'] == 'COLORADO'].copy()

# Get unique counts (value_counts defaults to NOT count blanks)
state_50_scales = state_50_df['TOR_F_SCALE'].value_counts()
state_60_scales = state_60_df['TOR_F_SCALE'].value_counts()
state_70_scales = state_70_df['TOR_F_SCALE'].value_counts()
state_80_scales = state_80_df['TOR_F_SCALE'].value_counts()
state_90_scales = state_90_df['TOR_F_SCALE'].value_counts()
state_00_scales = state_00_df['TOR_F_SCALE'].value_counts()
state_10_scales = state_10_df['TOR_F_SCALE'].value_counts()

# Build the plot
# Setup the bar plot for the 6 levels
state_levels_50 = formatDataForPlotting(state_50_scales, "50")
                  
state_levels_60 = formatDataForPlotting(state_60_scales, "60")
                  
state_levels_70 = formatDataForPlotting(state_70_scales, "70")
                  
state_levels_80 = formatDataForPlotting(state_80_scales, "80")
                  
state_levels_90 = formatDataForPlotting(state_90_scales, "90")
                  
state_levels_00 = formatDataForPlotting(state_00_scales, "00")
                                
state_levels_10 = formatDataForPlotting(state_10_scales, "10")

# Set up the bar chart
x_axis = ['F0/EF0', 'F1/EF1', 'F2/EF2', 'F3/EF3', 'F4/EF4', 'F5/EF5']
_x_axis = np.arange(len(x_axis))

plt.bar(_x_axis - 0.3, state_levels_50, width=0.1, label="1950s")
plt.bar(_x_axis - 0.2, state_levels_60, width=0.1, label="1960s")
plt.bar(_x_axis - 0.1, state_levels_70, width=0.1, label="1970s")
plt.bar(_x_axis - 0.0, state_levels_80, width=0.1, label="1980s")
plt.bar(_x_axis + 0.1, state_levels_90, width=0.1, label="1990s")
plt.bar(_x_axis + 0.2, state_levels_00, width=0.1, label="2000s")
plt.bar(_x_axis + 0.3, state_levels_10, width=0.1, label="2010s")
plt.xticks(_x_axis, x_axis) # set labels manually

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='y', alpha=0.4)
plt.xlabel("F/EF Level", fontsize = 22)
plt.ylabel("Number of Tornados", fontsize = 22)
plt.title('Number of Tornados by F/EF Scale (COLORADO)', fontsize = 26)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/number_tornados_scale_colorado.png", bbox_inches="tight")

# %%
# Show plot
plt.show()

# %%
#
# Get the counts (of each strength category) for the 6 original torado alley states
# One plot per state
# THIS ONE IS FOR SOUTH DAKOTA
#

# Count the unique scales (if NaN, discarded)
state_50_df = decade_50_df.loc[decade_50_df['STATE'] == 'SOUTH DAKOTA'].copy()
state_60_df = decade_60_df.loc[decade_60_df['STATE'] == 'SOUTH DAKOTA'].copy()
state_70_df = decade_70_df.loc[decade_70_df['STATE'] == 'SOUTH DAKOTA'].copy()
state_80_df = decade_80_df.loc[decade_80_df['STATE'] == 'SOUTH DAKOTA'].copy()
state_90_df = decade_90_df.loc[decade_90_df['STATE'] == 'SOUTH DAKOTA'].copy()
state_00_df = decade_00_df.loc[decade_00_df['STATE'] == 'SOUTH DAKOTA'].copy()
state_10_df = decade_10_df.loc[decade_10_df['STATE'] == 'SOUTH DAKOTA'].copy()

# Get unique counts (value_counts defaults to NOT count blanks)
state_50_scales = state_50_df['TOR_F_SCALE'].value_counts()
state_60_scales = state_60_df['TOR_F_SCALE'].value_counts()
state_70_scales = state_70_df['TOR_F_SCALE'].value_counts()
state_80_scales = state_80_df['TOR_F_SCALE'].value_counts()
state_90_scales = state_90_df['TOR_F_SCALE'].value_counts()
state_00_scales = state_00_df['TOR_F_SCALE'].value_counts()
state_10_scales = state_10_df['TOR_F_SCALE'].value_counts()

# Build the plot
# Setup the bar plot for the 6 levels
state_levels_50 = formatDataForPlotting(state_50_scales, "50")
                  
state_levels_60 = formatDataForPlotting(state_60_scales, "60")
                  
state_levels_70 = formatDataForPlotting(state_70_scales, "70")
                  
state_levels_80 = formatDataForPlotting(state_80_scales, "80")
                  
state_levels_90 = formatDataForPlotting(state_90_scales, "90")
                  
state_levels_00 = formatDataForPlotting(state_00_scales, "00")
                                
state_levels_10 = formatDataForPlotting(state_10_scales, "10")

# Set up the bar chart
x_axis = ['F0/EF0', 'F1/EF1', 'F2/EF2', 'F3/EF3', 'F4/EF4', 'F5/EF5']
_x_axis = np.arange(len(x_axis))

plt.bar(_x_axis - 0.3, state_levels_50, width=0.1, label="1950s")
plt.bar(_x_axis - 0.2, state_levels_60, width=0.1, label="1960s")
plt.bar(_x_axis - 0.1, state_levels_70, width=0.1, label="1970s")
plt.bar(_x_axis - 0.0, state_levels_80, width=0.1, label="1980s")
plt.bar(_x_axis + 0.1, state_levels_90, width=0.1, label="1990s")
plt.bar(_x_axis + 0.2, state_levels_00, width=0.1, label="2000s")
plt.bar(_x_axis + 0.3, state_levels_10, width=0.1, label="2010s")
plt.xticks(_x_axis, x_axis) # set labels manually

plt.legend(loc='upper right', fontsize = 15)

plt.grid(axis='y', alpha=0.4)
plt.xlabel("F/EF Level", fontsize = 22)
plt.ylabel("Number of Tornados", fontsize = 22)
plt.title('Number of Tornados by F/EF Scale (SOUTH DAKOTA)', fontsize = 26)

plt.rcParams['figure.figsize'] = (20,12)

plt.rc('xtick',labelsize=20)
plt.rc('ytick',labelsize=20)

# Save Figure
plt.savefig("images/number_tornados_scale_south_dakota.png", bbox_inches="tight")

# %%
# Show plot
plt.show()
